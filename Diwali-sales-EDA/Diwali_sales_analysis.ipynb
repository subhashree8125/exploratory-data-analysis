# %%
# @title Default title text
import pandas as pd                   # For data handling
import seaborn as sns                 # For plotting graphs
import matplotlib.pyplot as plt

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Specify the path to the CSV file in your Drive
path = "/content/Copy of Diwali_Sales_Data.csv"

# Read the CSV file and gather the data
df = pd.read_csv(path,index_col=0, encoding='windows-1252')
print(df)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#            Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# User_ID
# 1002903    Sanskriti  P00125942      F     26-35   28               0
# 1000732       Kartik  P00110942      F     26-35   35               1
# 1001990        Bindu  P00118542      F     26-35   35               1
# 1001425       Sudevi  P00237842      M      0-17   16               0
# 1000588         Joni  P00057942      M     26-35   28               1
# ...              ...        ...    ...       ...  ...             ...
# 1000695      Manning  P00296942      M     18-25   19               1
# 1004089  Reichenbach  P00171342      M     26-35   33               0
# 1001209        Oshin  P00201342      F     36-45   40               0
# 1004023       Noonan  P00059442      M     36-45   37               0
# ...

# %%
#commands used to create a new figure and ticks in the graph
plt.figure(figsize=(10, 8))
plt.xticks(rotation=45)

category_sales = df.groupby('Occupation')['Age Group'].count()
category_sales.plot(x='Occupation', y='Age Group', kind='bar')
#configure the grid lines
plt.grid()

# Commands which mark the label name in y and x axis with the title of the graph
plt.title('Sales Contribution by Zone')
plt.ylabel('occupution')
plt.xlabel('Age Group')
#Commands to adjust the subplot and to disply the plot.
plt.tight_layout()
plt.show()

# %%
category_sales = df.groupby(['Occupation', 'Gender']).size().unstack()


# Plot with separate colors for Male and Female
category_sales.plot(kind='bar', color=['blue', 'pink'])


# Title and labels
plt.title('Sales Contribution by Zone')
plt.ylabel('Count')
plt.xlabel('Occupation')
# Out:
# Text(0.5, 0, 'Occupation')

# %% [markdown]
# 1.Classifying quantity of sales on the bases of Category of
# product and Gender.

# %%
sns.countplot(data=df, x='Product_Category', hue='Gender')
# Directly plot the crosstab
table.plot(kind='bar', figsize=(10, 6))



plt.xticks(rotation=90)
plt.legend(title='Gender')
plt.tight_layout()
plt.show()

# %% [markdown]
# 2.Classifying Revenue from sales on the bases of Category of
# product and Gender.

# %%
# Group by Product Category and Gender, and sum Amount
result = df.groupby(['Product_Category', 'Gender'])['Amount'].sum().unstack()

# Print result (optional)
print("\nTotal Amount by Category and Gender:\n")
print(result)

# Plot
result.plot(kind='bar', figsize=(10, 6))
plt.title('Total Amount by Product Category and Gender')
plt.xlabel('Product Category')
plt.ylabel('Total Amount')
plt.xticks(rotation=90)
plt.legend(title='Gender')
plt.tight_layout()
plt.show()
# Out:
# Total Amount by Category and Gender:
#
# Gender                           F          M
# Product_Category
# Auto                    1285791.99   672818.0
# Beauty                  1524257.00   435227.0
# Books                    404215.00   657263.0
# Clothing & Apparel     11479103.00  5015916.0
# Decor                    596994.00   133366.0
# Electronics & Gadgets  11033097.00  4610749.0
# Food                   24176102.50  9757781.0
# Footwear & Shoes       11534547.45  4040662.0
# Furniture               3394642.99  2045409.0
# Games & Toys            3045258.00  1286436.0
# Hand & Power Tools       127100.00   278518.0
# Household items          859644.00   709693.0
# Office                    54983.00    26953.0
# Pet Care                 331509.00   150768.0
# Sports Products         2675513.00   960420.0
# Stationery               891897.50   784154.0
# Tupperware               830965.00   324677.0
# Veterinary                90236.00    22466.0

# %% [markdown]
# 3.Analyzing sales w.r.t Age Group and Occupation.

# %%
result = df.groupby(['Age Group', 'Occupation'])['Amount'].count()
print(result)
plt.figure(figsize=(12, 6))

# Plotting using Seaborn's countplot
sns.countplot(data=df, x='Age Group', hue='Occupation')

# Customize the plot
plt.title('Product Purchase Count by Age Group and Occupation')
plt.xlabel('Age Group')
plt.ylabel('Number of Products Sold')
plt.legend(title='Occupation', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# Age Group  Occupation
# 0-17       Agriculture     9
#            Automobile     11
#            Aviation       29
#            Banking        20
#            Chemical       12
#                           ..
# 55+        IT Sector      64
#            Lawyer         20
#            Media          33
#            Retail         19
#            Textile        18
# Name: Amount, Length: 105, dtype: int64

# %% [markdown]
# 4.which product category has more profit margin?

# %%
# Group by Product Category and calculate average Amount
grouped = df.groupby('Product_Category')['Amount'].mean()
print(grouped)
# Find the top category
top = grouped.idxmax()
print(f"\n✅ Category with highest average amount: {top}")

# Plot the average amount by category
plt.figure(figsize=(10,6))
grouped.sort_values().plot(kind='bar', color='skyblue')
plt.title('Average Amount by Product Category')
plt.xlabel('Average Amount')
plt.ylabel('Product Category')

# Highlight the top category

plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Product_Category
# Auto                     20191.855567
# Beauty                    4643.327014
# Books                    10305.611650
# Clothing & Apparel        6212.813183
# Decor                     7607.916667
# Electronics & Gadgets     7495.853378
# Food                     13628.065663
# Footwear & Shoes         14707.468791
# Furniture                15454.693153
# Games & Toys             11222.005181
# Hand & Power Tools       15600.692308
# Household items           3017.955769
# Office                     725.097345
# Pet Care                  2274.891509
# Sports Products          10213.294944
# Stationery               14964.745536
# Tupperware               16050.583333
# Veterinary                1391.382716
# Name: Amount, dtype: float64
#
# ✅ Category with highest average amount: Auto

# %% [markdown]
# ```
# 5.which product category has more revenue generated?
# ```

# %%
# Group by Product Category and sum the Amount (Revenue)
revenue_by_category = df.groupby('Product_Category')['Amount'].sum()

# Print all revenues
print("\nRevenue generated by each Product Category:\n")
print(revenue_by_category)

# Find and print the top category
top_category = revenue_by_category.idxmax()
top_revenue = revenue_by_category.max()
print(f"\n✅ Category with the highest revenue: {top_category} ({top_revenue:.2f})")

# Plotting
plt.figure(figsize=(10, 6))
revenue_by_category.sort_values().plot(kind='barh', color='lightgreen')
plt.title('Revenue by Product Category')
plt.xlabel('Total Revenue')
plt.ylabel('Product Category')

# Highlight top category with a line
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Revenue generated by each Product Category:
#
# Product_Category
# Auto                      1958609.99
# Beauty                    1959484.00
# Books                     1061478.00
# Clothing & Apparel       16495019.00
# Decor                      730360.00
# Electronics & Gadgets    15643846.00
# Food                     33933883.50
# Footwear & Shoes         15575209.45
# Furniture                 5440051.99
# Games & Toys              4331694.00
# Hand & Power Tools         405618.00
# Household items           1569337.00
# Office                      81936.00
# Pet Care                   482277.00
# Sports Products           3635933.00
# Stationery                1676051.50
# Tupperware                1155642.00
# Veterinary                 112702.00
# Name: Amount, dtype: float64
#
# ✅ Category with the highest revenue: Food (33933883.50)

# %% [markdown]
# 6.Which state has more orders?

# %%
# Count number of orders per state (assuming each row is one order)
orders_by_state = df['State'].value_counts().sort_values(ascending=True)

# Print the sorted order counts
print("\nNumber of Orders by State (Highest to Lowest):\n")
print(orders_by_state)

# Plotting
plt.figure(figsize=(10, 6))
orders_by_state.plot(kind='bar', color='lightcoral')
plt.title('Number of Orders by State')
plt.xlabel('State')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Number of Orders by State (Highest to Lowest):
#
# State
# Telangana            125
# Punjab               200
# Rajasthan            231
# Uttarakhand          320
# Jharkhand            380
# Gujarat              429
# Bihar                434
# Haryana              452
# Kerala               453
# Himachal Pradesh     608
# Andhra Pradesh       812
# Madhya Pradesh       923
# Delhi               1107
# Karnataka           1305
# Maharashtra         1526
# Uttar Pradesh       1946
# Name: count, dtype: int64

# %% [markdown]
# 7.Which marital status has given more sales?

# %%
# Group by Marital_Status and sum the Amount
sales_by_marital_status = df.groupby('Marital_Status')['Amount'].sum()

# Print the result
print("\nTotal Sales by Marital Status:\n")
print(sales_by_marital_status)

# Plotting
plt.figure(figsize=(6, 4))
sales_by_marital_status.plot(kind='pie', color=["lightgreen","lightcoral"])
plt.title('Total Sales by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Total Sales Amount')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# Total Sales by Marital Status:
#
# Marital_Status
# 0    62125386.44
# 1    44123745.99
# Name: Amount, dtype: float64

# %% [markdown]
# 8.Maximum Sales is happening from which state?

# %%
# Group by State and sum the Amount
sales_by_state = df.groupby('State')['Amount'].sum()

# Print all states and their total sales
print("\nTotal Sales by State:\n")
print(sales_by_state.sort_values(ascending=False))

# Find the state with the highest sales
top_state = sales_by_state.idxmax()
top_sales = sales_by_state.max()
print(f"\n✅ State with the maximum sales: {top_state} ({top_sales:.2f})")

plt.figure(figsize=(10, 6))
sales_by_state.sort_values().plot(kind='bar', color='mediumorchid')
plt.title('Total Sales by State')
plt.xlabel('Total Sales Amount')
plt.ylabel('State')
plt.tight_layout()
plt.show()
# Out:
# Total Sales by State:
#
# State
# Uttar Pradesh       19374968.00
# Maharashtra         14427543.00
# Karnataka           13523540.00
# Delhi               11603819.45
# Madhya Pradesh       8101142.00
# Andhra Pradesh       8037146.99
# Himachal Pradesh     4963368.00
# Haryana              4220175.00
# Bihar                4022757.00
# Gujarat              3946082.00
# Kerala               3894491.99
# Jharkhand            3026456.00
# Uttarakhand          2520944.00
# Rajasthan            1909409.00
# Punjab               1525800.00
# Telangana            1151490.00
# Name: Amount, dtype: float64
#
# ✅ State with the maximum sales: Uttar Pradesh (19374968.00)

# %%
# Create a pivot table of counts (Age Group vs Product Category)
heatmap_data = df.pivot_table(index='Age Group', columns='Product_Category', values='Product_ID', aggfunc='count', fill_value=0)
print(heatmap_data)
plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, annot=True, fmt='d', cmap='YlGnBu')

# Customizing the heatmap
plt.title('Product Categories Bought by Age Group (Heatmap)')
plt.xlabel('Product Category')
plt.ylabel('Age Group')
plt.tight_layout()
plt.show()
# Out:
# Product_Category  Auto  Beauty  Books  Clothing & Apparel  Decor  \
# Age Group
# 0-17                 3       9      1                  72      1
# 18-25               17      77     20                 469     19
# 26-35               43     164     41                1057     33
# 36-45               18      82     22                 532     23
# 46-50                6      33      9                 234     10
# 51-55                8      37      7                 188      5
# 55+                  5      20      3                 103      5
#
# Product_Category  Electronics & Gadgets  Food  Footwear & Shoes  Furniture  \
# Age Group
# 0-17                                 61    83                 6         13
# 18-25                               343   478                45         68
# 26-35                               832   992               424        137
# 36-45                               413   456               306         69
# ...
